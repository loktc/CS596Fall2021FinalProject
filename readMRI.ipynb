# %%
import pydicom
import matplotlib.pyplot as plt
import scipy.misc

in_path = '/Users/twinkle/Documents/GitHub/CS596Fall2021FinalProject/loni/ADNI/002_S_0619/B1-Calibration_PA/2008-08-13_15_36_09.0/I116115/ADNI_002_S_0619_MR_B1-Calibration_PA__br_raw_20080813230058722_83_S55370_I116115.dcm'
out_path = '/Users/twinkle/Desktop/output.jpg'
ds = pydicom.read_file(in_path)
img = ds.pixel_array
print(img.shape)
plt.imshow(img)
plt.show()
plt.imsave(out_path,img)
# Out:
# (256, 256)
